# %% [markdown]
# # Colab Quickstart

# %%
# !git clone --recursive --branch user/lorenzo-de-marco --single-branch https://github.com/sapeirone/aml-2025-mistake-detection.git code

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# TODO: update the paths below with your own

# !mkdir code/data
# !cp -r "/content/drive/MyDrive/Aml/features/video" -d code/data/

# !mkdir code/checkpoints
# !cp -r "/content/drive/MyDrive/Aml/error_recognition_best" -d code/checkpoints/

# %%
# !pip install torcheval

# %%
# !pip install -r code/requirements.txt

# %%
import wandb
wandb.login()

# %%
# %%bash
#
# cd code
# python train_er.py --variant LSTM --backbone omnivore --task_name ERROR_RECOGNITION
